# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('homeprices.csv')

# %%
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['area'], df['price'], color='red', marker='+')

# %%
model = LinearRegression()
model.fit(df[['area']], df['price'])
model.predict([[3000]])
# Out:
# /home/afsal/.local/lib/python3.10/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([587979.45205479])

# %%
co, y_int = model.coef_, model.intercept_
y = co*3000 + y_int
y
# Out:
# array([587979.45205479])

# %%
area_df = pd.read_csv('areas.csv')

# %%
result = model.predict(area_df)
area_df['prices'] = result

# %%
area_df.to_csv('result.csv')

# %%
plt.scatter(df['area'], df['price'], color='red', marker='+')
plt.plot(df['area'], model.predict(df[['area']]))
