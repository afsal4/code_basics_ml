# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from word2number import w2n
import numpy as np

# %%
df = pd.read_csv('/home/afsal/Desktop/vs_code/afsal_python/cs50_ai/ml/code_basics/week_2/hiring.csv')

# %%
df.head()
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000

# %%
df['experience'] = df['experience'].fillna('zero')
df.experience = df.experience.apply(w2n.word_to_num)

# %%
# creating model
model = LinearRegression()
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(df['test_score(out of 10)'].median())

x = df.iloc[:, :-1]
y = df['salary($)']
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    8.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.plot(x, y)
# Out:
# [<matplotlib.lines.Line2D at 0x7f96dba9a3e0>,
#  <matplotlib.lines.Line2D at 0x7f96dba9a410>,
#  <matplotlib.lines.Line2D at 0x7f96dba9a500>]

# %%
model.predict([[2, 9, 6]]), model.predict([[12, 10, 10]])
# Out:
# /home/afsal/.local/lib/python3.10/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /home/afsal/.local/lib/python3.10/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# (array([53205.96797671]), array([92002.18340611]))
